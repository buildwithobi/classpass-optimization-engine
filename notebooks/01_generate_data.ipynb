# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.data.data_generator import generate_classpass_data

# %%
df = generate_classpass_data(50000)
df.to_csv("../data/classpass_data.csv", index = False)

df["prob"].describe()
# Out:
# count    50000.000000
# mean         0.391562
# std          0.156720
# min          0.069474
# 25%          0.269970
# 50%          0.375468
# 75%          0.500728
# max          0.899153
# Name: prob, dtype: float64

# %%
df.head()
# Out:
#             persona          class_type  credit_price  current_streak  \
# 0   Balanced Burner  Heated Mat Pilates            20              77
# 1      Mindful Muse              Lagree            10              44
# 2  Pilates Princess  Heated Mat Pilates            10              36
# 3      Mindful Muse                HIIT             7              95
# 4      Mindful Muse         Yoga Sculpt            10              14
#
#    social_score  days_since_last_booking      prob  booked
# 0      0.411497                       15  0.367827       0
# 1      0.693939                       23  0.308226       0
# 2      0.460541                       25  0.345308       0
# 3      0.998785                        2  0.712901       1
# 4      0.426685                       15  0.526145       1

# %%
df["booked"].mean()
# Out:
# np.float64(0.3907)
